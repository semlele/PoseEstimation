# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from pylab import rcParams
rcParams['figure.figsize'] = 16,16
plt.rcParams['font.family'] = 'Hiragino Sans'

#出力された2d推定結果を読み込み
df= pd.read_csv('./ildoonet-tf-pose-estimation/movie/data/walking/cmu_walking_2ddata.csv')

#部位ごとにdfに格納
df_Nose = df[(df['human'] ==1) & (df['point'] == 0)]
df_Neck = df[(df['human'] ==1) & (df['point'] == 1)]
df_RShoulder = df[(df['human'] ==1) & (df['point'] == 2)]
df_RElbow = df[(df['human'] ==1) & (df['point'] == 3)]
df_RWrist = df[(df['human'] ==1) & (df['point'] == 4)]
df_LShoulder = df[(df['human'] ==1) & (df['point'] == 5)]
df_LElbow = df[(df['human'] ==1) & (df['point'] == 6)]
df_LWrist = df[(df['human'] ==1) & (df['point'] == 7)]
df_RHip = df[(df['human'] ==1) & (df['point'] == 8)]
df_RKnee = df[(df['human'] ==1) & (df['point'] == 9)]
df_RAnkle = df[(df['human'] ==1) & (df['point'] == 10)]
df_LHip = df[(df['human'] ==1) & (df['point'] == 11)]
df_LKnee = df[(df['human'] ==1) & (df['point'] == 12)]
df_LAnkle = df[(df['human'] ==1) & (df['point'] == 13)]
df_REye = df[(df['human'] ==1) & (df['point'] == 14)]
df_LEye = df[(df['human'] ==1) & (df['point'] == 15)]
df_REar = df[(df['human'] ==1) & (df['point'] == 16)]
df_LEar = df[(df['human'] ==1) & (df['point'] == 17)]
df_Background = df[(df['human'] ==1) & (df['point'] == 18)]

#2d推定座標をプロット
plt.title("動画 (walking.mp4) を2Dで骨格推定し、その座標変化を時系列でプロット (1point: 5frame)")
plt.xlabel("x軸方向")
plt.ylabel("y軸方向")

plt.plot(df_Nose['x'], -df_Nose['y'], label="Nose",marker = 'o')
plt.plot(df_RShoulder['x'], -df_RShoulder['y'], label="RSho",marker = 'o')
plt.plot(df_LShoulder['x'], -df_LShoulder['y'], label="LSho",marker = 'o')
plt.plot(df_RHip['x'], -df_RHip['y'], label="RHip",marker = 'o')
plt.plot(df_LHip['x'], -df_LHip['y'], label="LHip",marker = 'o')
plt.plot(df_RAnkle['x'], -df_RAnkle['y'], label="RAnk",marker = 'o')
plt.plot(df_LAnkle['x'], -df_LAnkle['y'], label="LAnk",marker = 'o')

plt.legend()
plt.show()

# %%
df_Nose
# Out:
#      Unnamed: 0  flame  human  point     x    y
# 0             0      0      1      0    34  163
# 10            0      5      1      0    34  165
# 20            0     10      1      0    34  167
# 30            0     20      1      0    43  163
# 40            0     25      1      0    47  160
# 50            0     30      1      0    58  156
# 62            0     35      1      0    65  154
# 74            0     40      1      0    76  154
# 86            0     45      1      0    83  154
# 100           0     50      1      0    94  151
# 115           0     55      1      0   101  149
# 129           0     60      1      0   114  149
# 146           0     65      1      0   123  149
# 163           0     70      1      0   141  151
# 180           0     75      1      0   153  149
# 197           0     80      1      0   175  149
# 214           0     85      1      0   188  147
# 231           0     90      1      0   213  145
# 248           0     95      1      0   229  143
# 262           0    100      1      0   256  143
# 277           0    105      1      0   276  145
# 292           0    110      1      0   310  149
# 307           0    115      1      0   332  151
# 322           0    120      1      0   372  151
# 337           0    125      1      0   399  149
# 352           0    130      1      0   435  147
# 369           0    135      1      0   469  145
# 384           0    140      1      0   491  145
# 401           0    145      1      0   527  147
# 417           0    150      1      0   554  149
# 433           0    155      1      0   595  151
# 449           0    160      1      0   622  151
# 465           0    165      1      0   664  147
# 479           0    170      1      0   689  143
# 493           0    175      1      0   716  140
# 507           0    180      1      0   754  143
# 520           0    185      1      0   783  147
# 534           0    190      1      0   826  149
# 548           0    195      1      0   855  149
# 562           0    200      1      0   900  143
# 573           0    205      1      0   929  143
# 587           0    210      1      0   969  143
# 601           0    215      1      0  1007  147
# 617           0    220      1      0  1034  147
# 633           0    225      1      0  1064  147
# 649           0    230      1      0  1106  147
# 665           0    235      1      0  1138  147
# 679           0    240      1      0  1180  145
# 693           0    245      1      0  1205  143
# 707           0    250      1      0  1241  140
# 721           0    255      1      0  1263  145
# 735           0    260      1      0  1299  149
# 749           0    265      1      0  1322  151
